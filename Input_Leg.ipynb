# %%
import pandas as pd

# %%
data = pd.DataFrame(columns=['Leg ID','Leg Type','Max weight (lbs)',
                             'Max Volume (CBM)','Movement Cost','Max. Pallet'])
data
# Out:
# Empty DataFrame
# Columns: [Leg ID, Leg Type, Max weight (lbs), Max Volume (CBM), Movement Cost, Max. Pallet]
# Index: []

# %%
apsheet = pd.read_excel('Full Monthe of OptiPro Data May 2022 revised 7.13 (1).xlsx',sheet_name='AP')
arsheet = pd.read_excel('Full Monthe of OptiPro Data May 2022 revised 7.13 (1).xlsx',sheet_name='AR')

# %%
apsheet.head()
# Out:
#        ME Id Customer ME             Order Type  \
# 0  834852500   834439605  Final Deconsolidation
# 1  835546500   835112436       partial shipment
# 2  835672700   835447591       partial shipment
# 3  835682600   835455631       partial shipment
# 4  835769200   835329209  Final Deconsolidation
#
#                               Account Hazmat     Status       Pickup Latest  \
# 0  TRANSPLACE CONSOLIDATION WORKGROUP     No  Delivered 2022-04-20 15:00:00
# 1  TRANSPLACE CONSOLIDATION WORKGROUP     No  Delivered 2022-04-29 13:00:00
# 2  TRANSPLACE CONSOLIDATION WORKGROUP     No  Delivered 2022-04-29 11:00:00
# 3  TRANSPLACE CONSOLIDATION WORKGROUP     No  Delivered 2022-04-29 12:00:00
# 4  TRANSPLACE CONSOLIDATION WORKGROUP     No  Delivered 2022-05-04 08:00:00
#
#       Delivery Latest Ready For Books Date/Time Origin City  ...  \
# 0 2022-04-22 15:00:00                2022-05-02   FULLERTON  ...
# 1 2022-05-02 09:30:00                2022-05-02    NAPOLEON  ...
# ...

# %%
pallets=[]
weight = []
volume=[]
# for i in range(len(apsheet)):
#     type_ = data['Leg Type'].iloc[i]
for j in range(len(apsheet)):
    if apsheet['Order Type'].iloc[j] == 'Final Deconsolidation':
        pallets.append(apsheet['Handling Unit Total'].iloc[j])
        weight.append(apsheet['Weight Total'].iloc[j])
        volume.append(apsheet['Cube Total'].iloc[j])
max_F_D_weight = max(weight)
max_F_D_volume= max(volume)
max_F_D_pallets = max(pallets)
# max_F_D_weight = apsheet['Expense (Payable) Total'].iloc[i]

# %%
pallets=[]
weight = []
volume=[]
# for i in range(len(apsheet)):
#     type_ = data['Leg Type'].iloc[i]
for j in range(len(apsheet)):
    if apsheet['Order Type'].iloc[j] == 'partial shipment':
        pallets.append(apsheet['Handling Unit Total'].iloc[j])
        weight.append(apsheet['Weight Total'].iloc[j])
        volume.append(apsheet['Cube Total'].iloc[j])
max_P_S_weight = max(weight)
max_P_S_volume= max(volume)
max_P_S_pallets = max(pallets)

# %%
pallets=[]
weight = []
volume=[]
# for i in range(len(apsheet)):
#     type_ = data['Leg Type'].iloc[i]
for j in range(len(apsheet)):
    if apsheet['Order Type'].iloc[j] == 'Sweep pick up to consolidation dock':
        pallets.append(apsheet['Handling Unit Total'].iloc[j])
        weight.append(apsheet['Weight Total'].iloc[j])
        volume.append(apsheet['Cube Total'].iloc[j])
max_sweep_weight = max(weight)
max_sweep_volume= max(volume)
max_sweep_pallets = max(pallets)

# %%
pallets=[]
weight = []
volume=[]
# for i in range(len(apsheet)):
#     type_ = data['Leg Type'].iloc[i]
for j in range(len(apsheet)):
    if apsheet['Order Type'].iloc[j] == 'Linehaul to Final Deconsolidation':
        pallets.append(apsheet['Handling Unit Total'].iloc[j])
        weight.append(apsheet['Weight Total'].iloc[j])
        volume.append(apsheet['Cube Total'].iloc[j])
max_line_weight = max(weight)
max_line_volume= max(volume)
max_line_pallets = max(pallets)

# %%
pallets=[]
weight = []
volume=[]
# for i in range(len(apsheet)):
#     type_ = data['Leg Type'].iloc[i]
for j in range(len(apsheet)):
    if apsheet['Order Type'].iloc[j] == 'coload':
        pallets.append(apsheet['Handling Unit Total'].iloc[j])
        weight.append(apsheet['Weight Total'].iloc[j])
        volume.append(apsheet['Cube Total'].iloc[j])
max_c_weight = max(weight)
max_c_volume= max(volume)
max_c_pallets = max(pallets)

# %%
for i in range(len(data)):
    if data['Leg Type'].iloc[i] == 'partial shipment':
        data['Max weight (lbs)'].iloc[i] = max_P_S_weight
        data['Max Volume (CBM)'].iloc[i] = max_P_S_volume
        data['Max. Pallet'].iloc[i] = max_P_S_pallets
# Out:
# C:\Users\bichu\AppData\Local\Temp\ipykernel_6740\3540330937.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Max weight (lbs)'].iloc[i] = max_P_S_weight
# C:\Users\bichu\AppData\Local\Temp\ipykernel_6740\3540330937.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Max Volume (CBM)'].iloc[i] = max_P_S_volume
# C:\Users\bichu\AppData\Local\Temp\ipykernel_6740\3540330937.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
for i in range(len(data)):
    if data['Leg Type'].iloc[i] == 'Sweep pick up to consolidation dock':
        data['Max weight (lbs)'].iloc[i] = max_sweep_weight
        data['Max Volume (CBM)'].iloc[i] = max_sweep_volume
        data['Max. Pallet'].iloc[i] = max_sweep_pallets
# Out:
# C:\Users\bichu\AppData\Local\Temp\ipykernel_6740\1437059591.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Max weight (lbs)'].iloc[i] = max_sweep_weight
# C:\Users\bichu\AppData\Local\Temp\ipykernel_6740\1437059591.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Max Volume (CBM)'].iloc[i] = max_sweep_volume
# C:\Users\bichu\AppData\Local\Temp\ipykernel_6740\1437059591.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
for i in range(len(data)):
    if data['Leg Type'].iloc[i] == 'Linehaul to Final Deconsolidation':
        data['Max weight (lbs)'].iloc[i] = max_line_weight
        data['Max Volume (CBM)'].iloc[i] = max_line_volume
        data['Max. Pallet'].iloc[i] = max_line_pallets
# Out:
# C:\Users\bichu\AppData\Local\Temp\ipykernel_6740\593338733.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Max weight (lbs)'].iloc[i] = max_line_weight
# C:\Users\bichu\AppData\Local\Temp\ipykernel_6740\593338733.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Max Volume (CBM)'].iloc[i] = max_line_volume
# C:\Users\bichu\AppData\Local\Temp\ipykernel_6740\593338733.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
for i in range(len(data)):
    if data['Leg Type'].iloc[i] == 'Final Deconsolidation':
        data['Max weight (lbs)'].iloc[i] = max_F_D_weight
        data['Max Volume (CBM)'].iloc[i] = max_F_D_volume
        data['Max. Pallet'].iloc[i] = max_F_D_pallets
# Out:
# C:\Users\bichu\AppData\Local\Temp\ipykernel_6740\3192970561.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Max weight (lbs)'].iloc[i] = max_F_D_weight
# C:\Users\bichu\AppData\Local\Temp\ipykernel_6740\3192970561.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Max Volume (CBM)'].iloc[i] = max_F_D_volume
# C:\Users\bichu\AppData\Local\Temp\ipykernel_6740\3192970561.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
pallets=[]
weight = []
volume=[]
# for i in range(len(apsheet)):
#     type_ = data['Leg Type'].iloc[i]
for j in range(len(apsheet)):
    if apsheet['Order Type'].iloc[j] == 'coload':
        pallets.append(apsheet['Handling Unit Total'].iloc[j])
        weight.append(apsheet['Weight Total'].iloc[j])
        volume.append(apsheet['Cube Total'].iloc[j])
cleanedvolume = [x for x in volume if str(x) != 'nan']
max_c_weight = max(weight)
max_c_volume= max(cleanedvolume)
max_c_pallets = max(pallets)

# %%
max(volume)
# Out:
# nan

# %%
for i in range(len(data)):
    if data['Leg Type'].iloc[i] == 'coload':
        data['Max weight (lbs)'].iloc[i] = max_c_weight
        data['Max Volume (CBM)'].iloc[i] = max_c_volume
        data['Max. Pallet'].iloc[i] = max_c_pallets
# Out:
# C:\Users\bichu\AppData\Local\Temp\ipykernel_6740\3539022192.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Max weight (lbs)'].iloc[i] = max_c_weight
# C:\Users\bichu\AppData\Local\Temp\ipykernel_6740\3539022192.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Max Volume (CBM)'].iloc[i] = max_c_volume
# C:\Users\bichu\AppData\Local\Temp\ipykernel_6740\3539022192.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
type(apsheet['Cube Total'].iloc[14])
# Out:
# numpy.float64

# %%
for i in range(len(data)):
    data['Movement Cost'].iloc[i] = apsheet['Expense (Payable) Total'].iloc[i]
# Out:
# C:\Users\bichu\AppData\Local\Temp\ipykernel_6740\3029853754.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Movement Cost'].iloc[i] = apsheet['Expense (Payable) Total'].iloc[i]

# %%
data.tail(50)
# Out:
#          Leg ID                           Leg Type Max weight (lbs)  \
# 1831  837447099              Final Deconsolidation         26761.39
# 1832  837447125              Final Deconsolidation         26761.39
# 1833  837498346              Final Deconsolidation         26761.39
# 1834  837498378              Final Deconsolidation         26761.39
# 1835  837498342              Final Deconsolidation         26761.39
# 1836  837447112              Final Deconsolidation         26761.39
# 1837  837447110              Final Deconsolidation         26761.39
# 1838  837447121              Final Deconsolidation         26761.39
# 1839  837838383              Final Deconsolidation         26761.39
# 1840  837838333  Linehaul to Final Deconsolidation          43076.2
# 1841  837687954              Final Deconsolidation         26761.39
# 1842  837374821  Linehaul to Final Deconsolidation          43076.2
# 1843  837687965              Final Deconsolidation         26761.39
# ...

# %%
data['Leg ID']=apsheet['ME Id']
data['Leg Type']=apsheet['Order Type']
# data['Max weight (lbs)']=''
# data['Max Volume (CBM)']=''
# data['Movement Cost']=28
# data['']=apsheet['Expense (Payable) Total']
data
# Out:
#          Leg ID               Leg Type Max weight (lbs) Max Volume (CBM)  \
# 0     834852500  Final Deconsolidation              NaN              NaN
# 1     835546500       partial shipment              NaN              NaN
# 2     835672700       partial shipment              NaN              NaN
# 3     835682600       partial shipment              NaN              NaN
# 4     835769200  Final Deconsolidation              NaN              NaN
# ...         ...                    ...              ...              ...
# 1876  837018010       partial shipment              NaN              NaN
# 1877  837308972       partial shipment              NaN              NaN
# 1878  835380009  Final Deconsolidation              NaN              NaN
# 1879  837687959  Final Deconsolidation              NaN              NaN
# 1880  836968546  Final Deconsolidation              NaN              NaN
#
#      Movement Cost Max. Pallet
# 0              NaN         NaN
# ...

# %%
data.to_excel('Input Leg Green.xlsx')
